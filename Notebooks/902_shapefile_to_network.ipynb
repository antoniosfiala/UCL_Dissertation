# %%
notebook_id = "902"

# %% [markdown]
# <a id="ID_top"></a>
# ## Country data organisation
#
# This workflow generates (part1), maintains (part2) and exports (part3)

# %% [markdown]
# #### Notebook sections:
#
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %% [markdown]
# #### Import all packages that could be required

# %%
# %load s_package_import.py
# package library, use to ensure consistency across notebooks, refresh periodically
# general packages
import os # use with os.listdir(_path_)
import requests
import csv
import time
from datetime import datetime
from shutil import copyfile

#temp check
#from shutil import make_archive
import zipfile #notebook

# data analysis packages
import pandas as pd
pd.options.display.max_columns = None # don't truncate columns
#pd.options.display.max_rows = None

import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import descartes
#import pycountry
from sklearn import preprocessing

# custom scripts
import s_file_export
import s_filepaths
import s_un_comtrade_extract as s_un
import s_adj_matrix_plot

#=== network analysis
import networkx as nx
#=== gavity modelling
#import gme as gme

#=== distance datasets

#import wbdata

# %% [markdown]
# #### Import module and declare path variables
# `import s_filepaths.py`

# %%
# import ref file
import s_filepaths

# declare local variables to work with
path_raw = s_filepaths.path_raw
path_raw_dl = s_filepaths.path_raw_dl
path_store = s_filepaths.path_store
path_live = s_filepaths.path_live
path_map = s_filepaths.path_map
path_image = s_filepaths.path_images

# %% [markdown]
# <a id="ID_part1"></a>
# ### Part 1
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %% [markdown]
# View all file in map folder

# %%
# View all files in live directory
print(os.listdir(f"{path_map}"))
# Out:
# ['ne_10m_railroads_europe_asia', 'ne_10m_railroads', '.DS_Store', 'ne_50m_admin_europe_asia_trim', 'ne_50m_admin_europe_asia', 'ne_10m_admin_0_sovereignty', 'test_CHN_rrd', 'ne_10m_populated_places', 'eu_asia_rail_country_joint_layer', 'ne_50m_admin_0_countries', 'test_mini', 'ne_10m_eu_asia_length', 'CH_RU_KZ_Test', 'live_dataset']

# %%
# Load shape file
print(os.listdir(f"{path_map}"))
folder = "live_dataset"
print(os.listdir(f"{path_map}/{folder}"))
file = "eurasia_simplified_1000000.shp"
china_shp_load = nx.read_shp(f"{path_map}/{folder}/{file}",geom_attrs=True)
# Out:
# ['ne_10m_railroads_europe_asia', 'ne_10m_railroads', '.DS_Store', 'ne_50m_admin_europe_asia_trim', 'ne_50m_admin_europe_asia', 'ne_10m_admin_0_sovereignty', 'test_CHN_rrd', 'ne_10m_populated_places', 'eu_asia_rail_country_joint_layer', 'ne_50m_admin_0_countries', 'test_mini', 'ne_10m_eu_asia_length', 'CH_RU_KZ_Test', 'live_dataset']
# ['eurasia_simplified_1000000.dbf', 'eurasia_simplified_1000000.shp', 'eurasia_simplified_1000000.shx', 'eurasia_simplified_1000000.prj', 'eurasia_simplified_1000000.qpj']

# %%
# Explore network())
print(len(china_shp_load.nodes()))
#china_shp_load.nodes(data = True)
#china_shp_load.edges(data = True)
# Out:
# 18300

# %%
# Visualise
vis_name = "whole_network_vis.png"
plt.figure(1,figsize = (60,60),dpi = 10)
nx.draw_spring(china_shp_load, with_labels = False, font_weight = "light",node_size=50,font_size=5, seed = 1)
plt.savefig(f"{path_image}{notebook_id}_{vis_name}",dpi = 100,transparent = True,pad_inches = 0,bbox_inches= "tight")

# %%
# filter nodes and edges
for edge in

# %%
# visualise
nx.draw(china_shp_load)

# %% [markdown]
# <a id="ID_part2"></a>
# ### Part 2
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %% [markdown]
# <a id="ID_part3"></a>
# ### Part 3
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %% [markdown]
# <a id="ID_part4"></a>
# ### Part 4
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %%
time_start = time.time()

# %%
time_end = time.time()
duration = time_end - time_start
print(duration)
# Out:
# 15.123659133911133

# %% [markdown]
# <a id="ID_part5"></a>
# ### Part 5
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||
