# %% [markdown]
# <a id="ID_top"></a>
# ## UNCOMTRADE API extractor
#
# Outline purpose of workflow.

# %% [markdown]
# #### Notebook sections:
#
# || [0|Top](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %% [markdown]
# #### Install all packages required

# %%
# %load s_package_import.py
# package library, use to ensure consistency across notebooks, refresh periodically
# general packages
import os # use with os.listdir(_path_)
import requests
import csv
import time
from datetime import datetime
from shutil import copyfile

# data analysis packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# custom scripts
import s_file_export
import s_filepaths
import s_un_comtrade_extract as s_un

#=== network analysis
import networkx as nx

# %%
# import ref file (in case above script is not triggered)
import s_filepaths

# declare local variables to work with
path_raw = s_filepaths.path_raw
path_raw_dl = s_filepaths.path_raw_dl
path_store = s_filepaths.path_store
path_live = s_filepaths.path_live

# %% [markdown]
# **Notebook settings**

# %%
create_ref_doc = True

# %% [markdown]
# <a id="ID_part1"></a>
# ### Set up fetching URL
# || [0|Top](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||
#
# Key for URL get headings, [here](https://comtrade.un.org/api/swagger/ui/index#!/Data/Data_GetData) || Reporter explanation, [here](https://comtrade.un.org/data/doc/api/#reporters) || Reporter ids [here](https://comtrade.un.org/Data/cache/reporterAreas.json)

# %%
if create_ref_doc:
    # test run, country 4 (AFG) as test case with only TOTAL trade for one year (2010), with no copy of file
    un_extract = s_un.f_un_comtrade_data(p_r_country = ["4"],p_p_country = ["all"],p_ps_years=["2010"],p_extra = "cc=TOTAL")
    s_file_export.f_df_export(un_extract[0][0],"un_com_0_test_ref",p_copy=False,p_loc1 = path_raw_dl)
else:
    print("Skipped")
# Out:
# WORKING ON | Country 4| URL https://comtrade.un.org/api/get?r=4&p=all&freq=A&ps=2010&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/store_un_com_0_test_ref_20200623_2147.csv | COMPLETE
# COPY   | SKIP

# %% [markdown]
# <a id="ID_part3"></a>
# ### Match to BRI reference countries
# || [0|Top](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||
#
# Take file from the UN comtrade extractor reference and match with list of BRI countries

# %%
#=== import (1) UN codes reference list
un_ref_data = pd.read_csv(f"{path_live}input_un_codes_ref.csv.gzip", compression="gzip")

try:
    un_ref_data.drop("Unnamed: 0",axis = 1,inplace = True)
except:
    pass

un_ref_data_clean = un_ref_data.reset_index(drop = True)

#=== import (2) BRI reference list
df_bri_list = pd.read_csv(f"{path_live}input_bri_countries_Dumor_Yao.csv.gzip", compression="gzip")

#=== match the two (1) & (2)
df_bri_matched = df_bri_list.merge(un_ref_data_clean,left_on = "iso_3",right_on = "pt3ISO")
df_bri_matched.head()
# Out:
#    Unnamed: 0 BRI_Country iso_3 pt3ISO  ptCode     ptTitle
# 0           0     Albania   ALB    ALB       8     Albania
# 1           1     Armenia   ARM    ARM      51     Armenia
# 2           2     Austria   AUT    AUT      40     Austria
# 3           3  Azerbaijan   AZE    AZE      31  Azerbaijan
# 4           4  Bangladesh   BGD    BGD      50  Bangladesh

# %% [markdown]
# <a id="ID_part4"></a>
# ### Loop through download
# || [0|Top](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %%
# URL settings
url_comma = "%2C"
url_add = "&"

extra_cc = f"cc=TOTAL"

# %%
# for every BRI country download data

df_collection = []
length = len(df_bri_matched.ptCode)

for index,entry in enumerate(list(df_bri_matched.ptCode)):
    #=== reporting
    temp_entry_name = list(df_bri_matched.BRI_Country)[index]
    print(f"Working on | {temp_entry_name} | {index+1}/{length} (~{round(((index+1)/length)*100)}%)")
    
    #=== run functions to extract
    dl_year = "2013"
    un_extract = s_un.f_un_comtrade_data(p_r_country = [str(entry)],p_p_country = ["all"],p_ps_years=[dl_year],p_extra = extra_cc)
    
    try:
        s_file_export.f_df_export(un_extract[0][0],f"un_com_{temp_entry_name}_{dl_year}_ref",p_copy=False,p_loc1=path_raw_dl,p_loc1_pre="dl_")
        df_collection.append(un_extract[0][0])
    except:
        df_collection.append(("Missing",entry))
# Out:
# Working on | Albania | 1/93 (~1%)
# WORKING ON | Country 8| URL https://comtrade.un.org/api/get?r=8&p=all&freq=A&ps=2013&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Albania_2013_ref_20200623_2232.csv | COMPLETE
# COPY   | SKIP
# Working on | Armenia | 2/93 (~2%)
# WORKING ON | Country 51| URL https://comtrade.un.org/api/get?r=51&p=all&freq=A&ps=2013&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Armenia_2013_ref_20200623_2232.csv | COMPLETE
# COPY   | SKIP
# Working on | Austria | 3/93 (~3%)
# WORKING ON | Country 40| URL https://comtrade.un.org/api/get?r=40&p=all&freq=A&ps=2013&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Austria_2013_ref_20200623_2232.csv | COMPLETE
# COPY   | SKIP
# Working on | Azerbaijan | 4/93 (~4%)
# WORKING ON | Country 31| URL https://comtrade.un.org/api/get?r=31&p=all&freq=A&ps=2013&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Azerbaijan_2013_ref_20200623_2232.csv | COMPLETE
# COPY   | SKIP
# Working on | Bangladesh | 5/93 (~5%)
# WORKING ON | Country 50| URL https://comtrade.un.org/api/get?r=50&p=all&freq=A&ps=2013&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Bangladesh_2013_ref_20200623_2232.csv | COMPLETE
# COPY   | SKIP
# Working on | Belarus | 6/93 (~6%)
# WORKING ON | Country 112| URL https://comtrade.un.org/api/get?r=112&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 112| URL https://comtrade.un.org/api/get?r=112&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Belgium | 7/93 (~8%)
# WORKING ON | Country 56| URL https://comtrade.un.org/api/get?r=56&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 56| URL https://comtrade.un.org/api/get?r=56&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Bhutan | 8/93 (~9%)
# WORKING ON | Country 64| URL https://comtrade.un.org/api/get?r=64&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 64| URL https://comtrade.un.org/api/get?r=64&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Bosnia and Herzegovina | 9/93 (~10%)
# WORKING ON | Country 70| URL https://comtrade.un.org/api/get?r=70&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 70| URL https://comtrade.un.org/api/get?r=70&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Brunei | 10/93 (~11%)
# WORKING ON | Country 96| URL https://comtrade.un.org/api/get?r=96&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 96| URL https://comtrade.un.org/api/get?r=96&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Darussalam | 11/93 (~12%)
# WORKING ON | Country 96| URL https://comtrade.un.org/api/get?r=96&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 96| URL https://comtrade.un.org/api/get?r=96&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Bulgaria | 12/93 (~13%)
# WORKING ON | Country 100| URL https://comtrade.un.org/api/get?r=100&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 100| URL https://comtrade.un.org/api/get?r=100&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Burundi | 13/93 (~14%)
# WORKING ON | Country 108| URL https://comtrade.un.org/api/get?r=108&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 108| URL https://comtrade.un.org/api/get?r=108&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Cambodia | 14/93 (~15%)
# WORKING ON | Country 116| URL https://comtrade.un.org/api/get?r=116&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 116| URL https://comtrade.un.org/api/get?r=116&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | China | 15/93 (~16%)
# WORKING ON | Country 156| URL https://comtrade.un.org/api/get?r=156&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 156| URL https://comtrade.un.org/api/get?r=156&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Croatia | 16/93 (~17%)
# WORKING ON | Country 191| URL https://comtrade.un.org/api/get?r=191&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 191| URL https://comtrade.un.org/api/get?r=191&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Czech Republic | 17/93 (~18%)
# WORKING ON | Country 203| URL https://comtrade.un.org/api/get?r=203&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 203| URL https://comtrade.un.org/api/get?r=203&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Denmark | 18/93 (~19%)
# WORKING ON | Country 208| URL https://comtrade.un.org/api/get?r=208&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 208| URL https://comtrade.un.org/api/get?r=208&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Djibouti | 19/93 (~20%)
# WORKING ON | Country 262| URL https://comtrade.un.org/api/get?r=262&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 262| URL https://comtrade.un.org/api/get?r=262&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Myanmar | 20/93 (~22%)
# WORKING ON | Country 104| URL https://comtrade.un.org/api/get?r=104&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 104| URL https://comtrade.un.org/api/get?r=104&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Egypt | 21/93 (~23%)
# WORKING ON | Country 818| URL https://comtrade.un.org/api/get?r=818&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 818| URL https://comtrade.un.org/api/get?r=818&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Estonia | 22/93 (~24%)
# WORKING ON | Country 233| URL https://comtrade.un.org/api/get?r=233&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 233| URL https://comtrade.un.org/api/get?r=233&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Ethiopia | 23/93 (~25%)
# WORKING ON | Country 231| URL https://comtrade.un.org/api/get?r=231&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 231| URL https://comtrade.un.org/api/get?r=231&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Finland | 24/93 (~26%)
# WORKING ON | Country 246| URL https://comtrade.un.org/api/get?r=246&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 246| URL https://comtrade.un.org/api/get?r=246&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | France | 25/93 (~27%)
# WORKING ON | Country 251| URL https://comtrade.un.org/api/get?r=251&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 251| URL https://comtrade.un.org/api/get?r=251&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Germany | 26/93 (~28%)
# WORKING ON | Country 276| URL https://comtrade.un.org/api/get?r=276&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 276| URL https://comtrade.un.org/api/get?r=276&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Greece | 27/93 (~29%)
# WORKING ON | Country 300| URL https://comtrade.un.org/api/get?r=300&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 300| URL https://comtrade.un.org/api/get?r=300&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Guinea | 28/93 (~30%)
# WORKING ON | Country 324| URL https://comtrade.un.org/api/get?r=324&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 324| URL https://comtrade.un.org/api/get?r=324&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Hungary | 29/93 (~31%)
# WORKING ON | Country 348| URL https://comtrade.un.org/api/get?r=348&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 348| URL https://comtrade.un.org/api/get?r=348&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Iceland | 30/93 (~32%)
# WORKING ON | Country 352| URL https://comtrade.un.org/api/get?r=352&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 352| URL https://comtrade.un.org/api/get?r=352&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Malaysia | 31/93 (~33%)
# WORKING ON | Country 458| URL https://comtrade.un.org/api/get?r=458&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 458| URL https://comtrade.un.org/api/get?r=458&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | India | 32/93 (~34%)
# WORKING ON | Country 699| URL https://comtrade.un.org/api/get?r=699&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 699| URL https://comtrade.un.org/api/get?r=699&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Indonesia | 33/93 (~35%)
# WORKING ON | Country 360| URL https://comtrade.un.org/api/get?r=360&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 360| URL https://comtrade.un.org/api/get?r=360&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Iran | 34/93 (~37%)
# WORKING ON | Country 364| URL https://comtrade.un.org/api/get?r=364&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 364| URL https://comtrade.un.org/api/get?r=364&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Iraq | 35/93 (~38%)
# WORKING ON | Country 368| URL https://comtrade.un.org/api/get?r=368&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 368| URL https://comtrade.un.org/api/get?r=368&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Ireland | 36/93 (~39%)
# WORKING ON | Country 372| URL https://comtrade.un.org/api/get?r=372&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 372| URL https://comtrade.un.org/api/get?r=372&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Israel | 37/93 (~40%)
# WORKING ON | Country 376| URL https://comtrade.un.org/api/get?r=376&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 376| URL https://comtrade.un.org/api/get?r=376&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Italy | 38/93 (~41%)
# WORKING ON | Country 381| URL https://comtrade.un.org/api/get?r=381&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 381| URL https://comtrade.un.org/api/get?r=381&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Jordan | 39/93 (~42%)
# WORKING ON | Country 400| URL https://comtrade.un.org/api/get?r=400&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 400| URL https://comtrade.un.org/api/get?r=400&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Kenya | 40/93 (~43%)
# WORKING ON | Country 404| URL https://comtrade.un.org/api/get?r=404&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 404| URL https://comtrade.un.org/api/get?r=404&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Kuwait | 41/93 (~44%)
# WORKING ON | Country 414| URL https://comtrade.un.org/api/get?r=414&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 414| URL https://comtrade.un.org/api/get?r=414&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Kyrgyz Republic | 42/93 (~45%)
# WORKING ON | Country 417| URL https://comtrade.un.org/api/get?r=417&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 417| URL https://comtrade.un.org/api/get?r=417&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Lao PDR | 43/93 (~46%)
# WORKING ON | Country 418| URL https://comtrade.un.org/api/get?r=418&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 418| URL https://comtrade.un.org/api/get?r=418&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Latvia | 44/93 (~47%)
# WORKING ON | Country 428| URL https://comtrade.un.org/api/get?r=428&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 428| URL https://comtrade.un.org/api/get?r=428&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Lebanon | 45/93 (~48%)
# WORKING ON | Country 422| URL https://comtrade.un.org/api/get?r=422&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 422| URL https://comtrade.un.org/api/get?r=422&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Lithuania | 46/93 (~49%)
# WORKING ON | Country 440| URL https://comtrade.un.org/api/get?r=440&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 440| URL https://comtrade.un.org/api/get?r=440&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Luxembourg | 47/93 (~51%)
# WORKING ON | Country 442| URL https://comtrade.un.org/api/get?r=442&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 442| URL https://comtrade.un.org/api/get?r=442&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Macedonia | 48/93 (~52%)
# WORKING ON | Country 807| URL https://comtrade.un.org/api/get?r=807&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 807| URL https://comtrade.un.org/api/get?r=807&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Portugal | 49/93 (~53%)
# WORKING ON | Country 620| URL https://comtrade.un.org/api/get?r=620&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 620| URL https://comtrade.un.org/api/get?r=620&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Madagascar | 50/93 (~54%)
# WORKING ON | Country 450| URL https://comtrade.un.org/api/get?r=450&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 450| URL https://comtrade.un.org/api/get?r=450&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Romania | 51/93 (~55%)
# WORKING ON | Country 642| URL https://comtrade.un.org/api/get?r=642&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 642| URL https://comtrade.un.org/api/get?r=642&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Maldives | 52/93 (~56%)
# WORKING ON | Country 462| URL https://comtrade.un.org/api/get?r=462&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 462| URL https://comtrade.un.org/api/get?r=462&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Malta | 53/93 (~57%)
# WORKING ON | Country 470| URL https://comtrade.un.org/api/get?r=470&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 470| URL https://comtrade.un.org/api/get?r=470&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Mauritania | 54/93 (~58%)
# WORKING ON | Country 478| URL https://comtrade.un.org/api/get?r=478&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 478| URL https://comtrade.un.org/api/get?r=478&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Mauritius | 55/93 (~59%)
# WORKING ON | Country 480| URL https://comtrade.un.org/api/get?r=480&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 480| URL https://comtrade.un.org/api/get?r=480&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Moldova | 56/93 (~60%)
# WORKING ON | Country 498| URL https://comtrade.un.org/api/get?r=498&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 498| URL https://comtrade.un.org/api/get?r=498&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Mongolia | 57/93 (~61%)
# WORKING ON | Country 496| URL https://comtrade.un.org/api/get?r=496&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 496| URL https://comtrade.un.org/api/get?r=496&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Morocco | 58/93 (~62%)
# WORKING ON | Country 504| URL https://comtrade.un.org/api/get?r=504&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 504| URL https://comtrade.un.org/api/get?r=504&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Mozambique | 59/93 (~63%)
# WORKING ON | Country 508| URL https://comtrade.un.org/api/get?r=508&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 508| URL https://comtrade.un.org/api/get?r=508&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Nepal | 60/93 (~65%)
# WORKING ON | Country 524| URL https://comtrade.un.org/api/get?r=524&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 524| URL https://comtrade.un.org/api/get?r=524&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Netherlands | 61/93 (~66%)
# WORKING ON | Country 528| URL https://comtrade.un.org/api/get?r=528&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 528| URL https://comtrade.un.org/api/get?r=528&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Norway | 62/93 (~67%)
# WORKING ON | Country 579| URL https://comtrade.un.org/api/get?r=579&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 579| URL https://comtrade.un.org/api/get?r=579&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Oman | 63/93 (~68%)
# WORKING ON | Country 512| URL https://comtrade.un.org/api/get?r=512&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 512| URL https://comtrade.un.org/api/get?r=512&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Pakistan | 64/93 (~69%)
# WORKING ON | Country 586| URL https://comtrade.un.org/api/get?r=586&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 586| URL https://comtrade.un.org/api/get?r=586&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Philippines | 65/93 (~70%)
# WORKING ON | Country 608| URL https://comtrade.un.org/api/get?r=608&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 608| URL https://comtrade.un.org/api/get?r=608&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Poland | 66/93 (~71%)
# WORKING ON | Country 616| URL https://comtrade.un.org/api/get?r=616&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 616| URL https://comtrade.un.org/api/get?r=616&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Turkmenistan | 67/93 (~72%)
# WORKING ON | Country 795| URL https://comtrade.un.org/api/get?r=795&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 795| URL https://comtrade.un.org/api/get?r=795&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Qatar | 68/93 (~73%)
# WORKING ON | Country 634| URL https://comtrade.un.org/api/get?r=634&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 634| URL https://comtrade.un.org/api/get?r=634&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Ukraine | 69/93 (~74%)
# WORKING ON | Country 804| URL https://comtrade.un.org/api/get?r=804&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 804| URL https://comtrade.un.org/api/get?r=804&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Russian Federation | 70/93 (~75%)
# WORKING ON | Country 643| URL https://comtrade.un.org/api/get?r=643&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 643| URL https://comtrade.un.org/api/get?r=643&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Rwanda | 71/93 (~76%)
# WORKING ON | Country 646| URL https://comtrade.un.org/api/get?r=646&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 646| URL https://comtrade.un.org/api/get?r=646&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Saudi Arabia | 72/93 (~77%)
# WORKING ON | Country 682| URL https://comtrade.un.org/api/get?r=682&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 682| URL https://comtrade.un.org/api/get?r=682&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Singapore | 73/93 (~78%)
# WORKING ON | Country 702| URL https://comtrade.un.org/api/get?r=702&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 702| URL https://comtrade.un.org/api/get?r=702&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Slovak Republic | 74/93 (~80%)
# WORKING ON | Country 703| URL https://comtrade.un.org/api/get?r=703&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 703| URL https://comtrade.un.org/api/get?r=703&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Slovenia | 75/93 (~81%)
# WORKING ON | Country 705| URL https://comtrade.un.org/api/get?r=705&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 705| URL https://comtrade.un.org/api/get?r=705&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Somalia | 76/93 (~82%)
# WORKING ON | Country 706| URL https://comtrade.un.org/api/get?r=706&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 706| URL https://comtrade.un.org/api/get?r=706&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Kazakhstan | 77/93 (~83%)
# WORKING ON | Country 398| URL https://comtrade.un.org/api/get?r=398&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 398| URL https://comtrade.un.org/api/get?r=398&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Sweden | 78/93 (~84%)
# WORKING ON | Country 752| URL https://comtrade.un.org/api/get?r=752&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 752| URL https://comtrade.un.org/api/get?r=752&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Switzerland | 79/93 (~85%)
# WORKING ON | Country 757| URL https://comtrade.un.org/api/get?r=757&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 757| URL https://comtrade.un.org/api/get?r=757&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Tajikistan | 80/93 (~86%)
# WORKING ON | Country 762| URL https://comtrade.un.org/api/get?r=762&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 762| URL https://comtrade.un.org/api/get?r=762&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Tanzania | 81/93 (~87%)
# WORKING ON | Country 834| URL https://comtrade.un.org/api/get?r=834&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 834| URL https://comtrade.un.org/api/get?r=834&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Thailand | 82/93 (~88%)
# WORKING ON | Country 764| URL https://comtrade.un.org/api/get?r=764&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 764| URL https://comtrade.un.org/api/get?r=764&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Tunisia | 83/93 (~89%)
# WORKING ON | Country 788| URL https://comtrade.un.org/api/get?r=788&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 788| URL https://comtrade.un.org/api/get?r=788&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Turkey | 84/93 (~90%)
# WORKING ON | Country 792| URL https://comtrade.un.org/api/get?r=792&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 792| URL https://comtrade.un.org/api/get?r=792&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Uganda | 85/93 (~91%)
# WORKING ON | Country 800| URL https://comtrade.un.org/api/get?r=800&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 800| URL https://comtrade.un.org/api/get?r=800&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | United Kingdom | 86/93 (~92%)
# WORKING ON | Country 826| URL https://comtrade.un.org/api/get?r=826&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 826| URL https://comtrade.un.org/api/get?r=826&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Uzbekistan | 87/93 (~94%)
# WORKING ON | Country 860| URL https://comtrade.un.org/api/get?r=860&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 860| URL https://comtrade.un.org/api/get?r=860&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Zambia | 88/93 (~95%)
# WORKING ON | Country 894| URL https://comtrade.un.org/api/get?r=894&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 894| URL https://comtrade.un.org/api/get?r=894&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Zimbabwe | 89/93 (~96%)
# WORKING ON | Country 716| URL https://comtrade.un.org/api/get?r=716&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 716| URL https://comtrade.un.org/api/get?r=716&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | South Africa | 90/93 (~97%)
# WORKING ON | Country 710| URL https://comtrade.un.org/api/get?r=710&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 710| URL https://comtrade.un.org/api/get?r=710&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Spain | 91/93 (~98%)
# WORKING ON | Country 724| URL https://comtrade.un.org/api/get?r=724&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 724| URL https://comtrade.un.org/api/get?r=724&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# Working on | Sri Lanka | 92/93 (~99%)
# WORKING ON | Country 144| URL https://comtrade.un.org/api/get?r=144&p=all&freq=A&ps=2013&cc=TOTAL
# DL ATTEMPT | Country 144| URL https://comtrade.un.org/api/get?r=144&p=all&freq=A&ps=2013&cc=TOTAL | not ok, data not processed further
# OBLIGATORY PAUSE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-d141a8384caa> in <module>
#      11     #=== run functions to extract
#      12     dl_year = "2013"
# ---> 13     un_extract = s_un.f_un_comtrade_data(p_r_country = [str(entry)],p_p_country = ["all"],p_ps_years=[dl_year],p_extra = extra_cc)
#      14
#      15     try:
#
# ~/Documents/Study/5_UCL/Modules/[3][60] Dissertation/GitRepo/UCL_Dissertation/Notebooks/s_un_comtrade_extract.py in f_un_comtrade_data(p_r_country, p_p_country, p_freq, p_ps_years, p_extra)
#     114
#     115         print("OBLIGATORY PAUSE")
# --> 116         time.sleep(2)
#     117
#     118
#
# KeyboardInterrupt:

# %%
# check number of entries (should be 93 regardless)
#len(df_collection)

# %%
# merge all dataframes
df_un_com_master = pd.concat(df_collection)
# save entire download to download folder
s_file_export.f_df_export(df_un_com_master,f"un_com_master_{dl_year}",p_copy= False,p_loc1=path_raw_dl,p_loc1_pre="dl_")
# Out:
# Export | ../Data/0_raw/1_auto_download/dl_un_com_master_2012_20200623_2230.csv | COMPLETE
# COPY   | SKIP

# %% [markdown]
# #### Clean dataframe and export to storage and live

# %%
            # Partner / reporter info (6)
columns =   ["rtCode","rt3ISO","rtTitle","ptCode","pt3ISO","ptTitle",
             # period and trade category and value information (3)
             "period","rgDesc","yr",
             
             # duplicate info? (6)
             "rgCode","cmdCode","TradeValue","periodDesc","pfCode","cmdDescE"]

df_un_com_focused = df_un_com_master.loc[:,columns]
df_un_com_focused.head()
# Out:
#    rtCode rt3ISO  rtTitle  ptCode pt3ISO      ptTitle  period  rgDesc    yr  \
# 0       8    ALB  Albania       0    WLD        World    2012  Import  2012
# 1       8    ALB  Albania       0    WLD        World    2012  Export  2012
# 2       8    ALB  Albania       4    AFG  Afghanistan    2012  Import  2012
# 3       8    ALB  Albania      12    DZA      Algeria    2012  Import  2012
# 4       8    ALB  Albania      12    DZA      Algeria    2012  Export  2012
#
#    rgCode cmdCode  TradeValue periodDesc pfCode         cmdDescE
# 0       1   TOTAL  4879829648       2012     H4  All Commodities
# 1       2   TOTAL  1967918947       2012     H4  All Commodities
# 2       1   TOTAL        2853       2012     H4  All Commodities
# 3       1   TOTAL     4304512       2012     H4  All Commodities
# 4       2   TOTAL      118342       2012     H4  All Commodities

# %%
# save year specific data frame
s_file_export.f_df_export(df_un_com_focused,f"un_com_{df_un_com_focused.yr.unique()[0]}")
# Out:
# Export | ../Data/1_raw_processed_backup/store_un_com_2012_20200623_2232.csv | COMPLETE
# COPY   | ../Data/2_raw_processed_input/input_un_com_2012.csv.gzip | COMPLETE

# %% [markdown]
# <a id="ID_part5"></a>
# ### Part 5
# || [0|Top](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||
