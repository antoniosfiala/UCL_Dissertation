# %%
notebook_id = "122"

# %% [markdown]
# <a id="ID_top"></a>
# ## UNCOMTRADE API extractor
#
# This workflow generates (part1), maintains (part2) and exports (part3)

# %% [markdown]
# #### Notebook sections:
#
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %% [markdown]
# #### Import all packages that could be required

# %%
# %load s_package_import.py
# package library, use to ensure consistency across notebooks, refresh periodically
# general packages
import os # use with os.listdir(_path_)
import requests
import csv
import time
from datetime import datetime
from shutil import copyfile

#temp check
#from shutil import make_archive
import zipfile #notebook

# data analysis packages
import pandas as pd
pd.options.display.max_columns = None # don't truncate columns
pd.options.display.max_rows = 150

import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import descartes
import pycountry

# custom scripts
import s_file_export
import s_filepaths
import s_un_comtrade_extract as s_un
import s_adj_matrix_plot

#=== network analysis
import networkx as nx
#=== gavity modelling
import gme as gme

#=== distance datasets
import wbdata

# %% [markdown]
# #### Import module and declare path variables
# `import s_filepaths.py`

# %%
# import ref file
import s_filepaths

# declare local variables to work with
path_raw = s_filepaths.path_raw
path_raw_dl = s_filepaths.path_raw_dl
path_store = s_filepaths.path_store
path_live = s_filepaths.path_live

# %% [markdown]
# <a id="ID_part1"></a>
# ### Part 1 | Load in scope countries
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %%
# View all files in live directory
print(os.listdir(f"{path_live}"))
# Out:
# ['121_input_di_matrix.csv.gzip', '.DS_Store', '112_input_gme_data.csv.gzip', '125_input_scope_country.csv.gzip', '120_input_scope_data.csv.gzip', '2_raw_explainer_doc.md', '121_input_de_matrix.csv.gzip', '113_input_bri_members.csv.gzip']

# %%
# load scope countries
filename = "120_input_scope_data.csv.gzip"
df_scope = pd.read_csv(f"{path_live}{filename}",compression = "gzip")

# isolate list of countries
list_countries = pd.DataFrame(list(df_scope.iso3_d.unique()),columns=["iso3"])
list_countries.head()
# Out:
#   iso3
# 0  ARE
# 1  AZE
# 2  BEL
# 3  CHN
# 4  CZE

# %% [markdown]
# **Generate UN code reference document**

# %%
create_ref_doc = False

# %%
if create_ref_doc:
    # test run, country 4 (AFG) as test case with only TOTAL trade for one year (2010), with no copy of file
    un_extract = s_un.f_un_comtrade_data(p_r_country = ["4"],p_p_country = ["all"],p_ps_years=["2010"],p_extra = "cc=TOTAL")
    s_file_export.f_df_export(un_extract[0][0],"un_com_0_test_ref",p_copy=False,p_loc1 = path_raw_dl)
else:
    print("Skipped")
# Out:
# Skipped

# %% [markdown]
# **Match scope countries to UN reference IDs**

# %%
# open raw file
print(os.listdir(f"{path_raw}"))
un_ref_file = pd.read_csv(f"{path_raw}un_codes_ref.csv.gzip",compression = "gzip")
un_ref_file = un_ref_file.loc[:,["pt3ISO","ptCode","ptTitle"]].copy() # only keep relevant columns
un_ref_file.set_index("pt3ISO", inplace= True) # set new index for matching
un_ref_file.head() # preview
# Out:
# ['un_codes_ref.csv.gzip', 'BRI_countries_online_MANUAL.csv', '.DS_Store', '0_raw_explainer_doc.md', 'bri_countries_manual_2020.csv.gzip', '121_raw_wb_distance_2016.csv.gzip', '1_auto_download', '112_raw_gme_raw_site_dl.csv.gzip']
#         ptCode              ptTitle
# pt3ISO
# WLD          0                World
# AFG          4          Afghanistan
# DZA         12              Algeria
# ATG         28  Antigua and Barbuda
# AZE         31           Azerbaijan

# %%
# matched list
df_merge = list_countries.merge(un_ref_file,how = "left",left_on="iso3",right_on=un_ref_file.index).copy()
df_merge.dropna(inplace = True)

# convert values
converted_list = []
for entry in df_merge.ptCode:
    temp_entry = str(int(entry))
    converted_list.append(temp_entry)
    
df_merge["ptCode"] = converted_list
df_merge.head()
# Out:
#   iso3 ptCode               ptTitle
# 0  ARE    784  United Arab Emirates
# 1  AZE     31            Azerbaijan
# 2  BEL     56               Belgium
# 3  CHN    156                 China
# 4  CZE    203               Czechia

# %% [markdown]
# <a id="ID_part2"></a>
# ### Part 2 | Extract UN data based on list
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %%
# URL settings
url_comma = "%2C"
url_add = "&"

extra_cc = f"cc=TOTAL"

# %%
# for every country is scope download data

df_collection = []
length = len(df_merge.ptCode)

for index,entry in enumerate(list(df_merge.ptCode)):
    #=== reporting
    temp_entry_name = list(df_merge.ptTitle)[index]
    print(f"Working on | {temp_entry_name} | {index+1}/{length} (~{round(((index+1)/length)*100)}%)")
    
    #=== run functions to extract
    dl_year = "2016"
    un_extract = s_un.f_un_comtrade_data(p_r_country = [str(int(entry))],p_p_country = ["all"],p_ps_years=[dl_year],p_extra = extra_cc)
            
    try:
        s_file_export.f_df_export(un_extract[0][0],f"un_com_{temp_entry_name}_{dl_year}_ref",p_copy=False,p_loc1=path_raw_dl,p_loc1_pre="dl_")
        df_collection.append(un_extract[0][0])
    except:
        df_collection.append(("Missing",entry))
# Out:
# Working on | United Arab Emirates | 1/84 (~1%)
# WORKING ON | Country 784| URL https://comtrade.un.org/api/get?r=784&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_United Arab Emirates_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Azerbaijan | 2/84 (~2%)
# WORKING ON | Country 31| URL https://comtrade.un.org/api/get?r=31&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Azerbaijan_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Belgium | 3/84 (~4%)
# WORKING ON | Country 56| URL https://comtrade.un.org/api/get?r=56&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Belgium_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | China | 4/84 (~5%)
# WORKING ON | Country 156| URL https://comtrade.un.org/api/get?r=156&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_China_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Czechia | 5/84 (~6%)
# WORKING ON | Country 203| URL https://comtrade.un.org/api/get?r=203&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Czechia_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Spain | 6/84 (~7%)
# WORKING ON | Country 724| URL https://comtrade.un.org/api/get?r=724&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Spain_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Georgia | 7/84 (~8%)
# WORKING ON | Country 268| URL https://comtrade.un.org/api/get?r=268&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Georgia_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Gibraltar | 8/84 (~10%)
# WORKING ON | Country 292| URL https://comtrade.un.org/api/get?r=292&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Gibraltar_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Hungary | 9/84 (~11%)
# WORKING ON | Country 348| URL https://comtrade.un.org/api/get?r=348&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Hungary_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Iraq | 10/84 (~12%)
# WORKING ON | Country 368| URL https://comtrade.un.org/api/get?r=368&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Iraq_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Italy | 11/84 (~13%)
# WORKING ON | Country 381| URL https://comtrade.un.org/api/get?r=381&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Italy_2016_ref_20200809_1322.csv | COMPLETE
# COPY   | SKIP
# Working on | Kyrgyzstan | 12/84 (~14%)
# WORKING ON | Country 417| URL https://comtrade.un.org/api/get?r=417&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Kyrgyzstan_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Rep. of Korea | 13/84 (~15%)
# WORKING ON | Country 410| URL https://comtrade.un.org/api/get?r=410&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Rep. of Korea_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Lithuania | 14/84 (~17%)
# WORKING ON | Country 440| URL https://comtrade.un.org/api/get?r=440&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Lithuania_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Oman | 15/84 (~18%)
# WORKING ON | Country 512| URL https://comtrade.un.org/api/get?r=512&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Oman_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Serbia | 16/84 (~19%)
# WORKING ON | Country 688| URL https://comtrade.un.org/api/get?r=688&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Serbia_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Sweden | 17/84 (~20%)
# WORKING ON | Country 752| URL https://comtrade.un.org/api/get?r=752&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Sweden_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Thailand | 18/84 (~21%)
# WORKING ON | Country 764| URL https://comtrade.un.org/api/get?r=764&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Thailand_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Tajikistan | 19/84 (~23%)
# WORKING ON | Country 762| URL https://comtrade.un.org/api/get?r=762&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Tajikistan_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Ukraine | 20/84 (~24%)
# WORKING ON | Country 804| URL https://comtrade.un.org/api/get?r=804&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Ukraine_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Viet Nam | 21/84 (~25%)
# WORKING ON | Country 704| URL https://comtrade.un.org/api/get?r=704&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Viet Nam_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Afghanistan | 22/84 (~26%)
# WORKING ON | Country 4| URL https://comtrade.un.org/api/get?r=4&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Afghanistan_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Albania | 23/84 (~27%)
# WORKING ON | Country 8| URL https://comtrade.un.org/api/get?r=8&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Albania_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Andorra | 24/84 (~29%)
# WORKING ON | Country 20| URL https://comtrade.un.org/api/get?r=20&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Andorra_2016_ref_20200809_1323.csv | COMPLETE
# COPY   | SKIP
# Working on | Armenia | 25/84 (~30%)
# WORKING ON | Country 51| URL https://comtrade.un.org/api/get?r=51&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Armenia_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Austria | 26/84 (~31%)
# WORKING ON | Country 40| URL https://comtrade.un.org/api/get?r=40&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Austria_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Bangladesh | 27/84 (~32%)
# WORKING ON | Country 50| URL https://comtrade.un.org/api/get?r=50&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Bangladesh_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Bulgaria | 28/84 (~33%)
# WORKING ON | Country 100| URL https://comtrade.un.org/api/get?r=100&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Bulgaria_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Bosnia Herzegovina | 29/84 (~35%)
# WORKING ON | Country 70| URL https://comtrade.un.org/api/get?r=70&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Bosnia Herzegovina_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Belarus | 30/84 (~36%)
# WORKING ON | Country 112| URL https://comtrade.un.org/api/get?r=112&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Belarus_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Brunei Darussalam | 31/84 (~37%)
# WORKING ON | Country 96| URL https://comtrade.un.org/api/get?r=96&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Brunei Darussalam_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Bhutan | 32/84 (~38%)
# WORKING ON | Country 64| URL https://comtrade.un.org/api/get?r=64&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Bhutan_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Switzerland | 33/84 (~39%)
# WORKING ON | Country 757| URL https://comtrade.un.org/api/get?r=757&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Switzerland_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Germany | 34/84 (~40%)
# WORKING ON | Country 276| URL https://comtrade.un.org/api/get?r=276&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Germany_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Denmark | 35/84 (~42%)
# WORKING ON | Country 208| URL https://comtrade.un.org/api/get?r=208&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Denmark_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Estonia | 36/84 (~43%)
# WORKING ON | Country 233| URL https://comtrade.un.org/api/get?r=233&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Estonia_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | Finland | 37/84 (~44%)
# WORKING ON | Country 246| URL https://comtrade.un.org/api/get?r=246&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Finland_2016_ref_20200809_1324.csv | COMPLETE
# COPY   | SKIP
# Working on | France | 38/84 (~45%)
# WORKING ON | Country 251| URL https://comtrade.un.org/api/get?r=251&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_France_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Faeroe Isds | 39/84 (~46%)
# WORKING ON | Country 234| URL https://comtrade.un.org/api/get?r=234&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Faeroe Isds_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Greece | 40/84 (~48%)
# WORKING ON | Country 300| URL https://comtrade.un.org/api/get?r=300&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Greece_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | China, Hong Kong SAR | 41/84 (~49%)
# WORKING ON | Country 344| URL https://comtrade.un.org/api/get?r=344&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_China, Hong Kong SAR_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Croatia | 42/84 (~50%)
# WORKING ON | Country 191| URL https://comtrade.un.org/api/get?r=191&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Croatia_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Indonesia | 43/84 (~51%)
# WORKING ON | Country 360| URL https://comtrade.un.org/api/get?r=360&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Indonesia_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | India | 44/84 (~52%)
# WORKING ON | Country 699| URL https://comtrade.un.org/api/get?r=699&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_India_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Ireland | 45/84 (~54%)
# WORKING ON | Country 372| URL https://comtrade.un.org/api/get?r=372&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Ireland_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Iran | 46/84 (~55%)
# WORKING ON | Country 364| URL https://comtrade.un.org/api/get?r=364&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Iran_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Israel | 47/84 (~56%)
# WORKING ON | Country 376| URL https://comtrade.un.org/api/get?r=376&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Israel_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Jordan | 48/84 (~57%)
# WORKING ON | Country 400| URL https://comtrade.un.org/api/get?r=400&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Jordan_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Kazakhstan | 49/84 (~58%)
# WORKING ON | Country 398| URL https://comtrade.un.org/api/get?r=398&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Kazakhstan_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Cambodia | 50/84 (~60%)
# WORKING ON | Country 116| URL https://comtrade.un.org/api/get?r=116&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Cambodia_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Kuwait | 51/84 (~61%)
# WORKING ON | Country 414| URL https://comtrade.un.org/api/get?r=414&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Kuwait_2016_ref_20200809_1325.csv | COMPLETE
# COPY   | SKIP
# Working on | Lao People's Dem. Rep. | 52/84 (~62%)
# WORKING ON | Country 418| URL https://comtrade.un.org/api/get?r=418&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Lao People's Dem. Rep._2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Lebanon | 53/84 (~63%)
# WORKING ON | Country 422| URL https://comtrade.un.org/api/get?r=422&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Lebanon_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Luxembourg | 54/84 (~64%)
# WORKING ON | Country 442| URL https://comtrade.un.org/api/get?r=442&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Luxembourg_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Latvia | 55/84 (~65%)
# WORKING ON | Country 428| URL https://comtrade.un.org/api/get?r=428&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Latvia_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | China, Macao SAR | 56/84 (~67%)
# WORKING ON | Country 446| URL https://comtrade.un.org/api/get?r=446&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_China, Macao SAR_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Rep. of Moldova | 57/84 (~68%)
# WORKING ON | Country 498| URL https://comtrade.un.org/api/get?r=498&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Rep. of Moldova_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | North Macedonia | 58/84 (~69%)
# WORKING ON | Country 807| URL https://comtrade.un.org/api/get?r=807&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_North Macedonia_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Myanmar | 59/84 (~70%)
# WORKING ON | Country 104| URL https://comtrade.un.org/api/get?r=104&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Myanmar_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Mongolia | 60/84 (~71%)
# WORKING ON | Country 496| URL https://comtrade.un.org/api/get?r=496&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Mongolia_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Montenegro | 61/84 (~73%)
# WORKING ON | Country 499| URL https://comtrade.un.org/api/get?r=499&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Montenegro_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Malaysia | 62/84 (~74%)
# WORKING ON | Country 458| URL https://comtrade.un.org/api/get?r=458&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Malaysia_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Netherlands | 63/84 (~75%)
# WORKING ON | Country 528| URL https://comtrade.un.org/api/get?r=528&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Netherlands_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Norway | 64/84 (~76%)
# WORKING ON | Country 579| URL https://comtrade.un.org/api/get?r=579&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Norway_2016_ref_20200809_1326.csv | COMPLETE
# COPY   | SKIP
# Working on | Nepal | 65/84 (~77%)
# WORKING ON | Country 524| URL https://comtrade.un.org/api/get?r=524&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Nepal_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Pakistan | 66/84 (~79%)
# WORKING ON | Country 586| URL https://comtrade.un.org/api/get?r=586&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Pakistan_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Poland | 67/84 (~80%)
# WORKING ON | Country 616| URL https://comtrade.un.org/api/get?r=616&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Poland_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Dem. People's Rep. of Korea | 68/84 (~81%)
# WORKING ON | Country 408| URL https://comtrade.un.org/api/get?r=408&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Dem. People's Rep. of Korea_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Portugal | 69/84 (~82%)
# WORKING ON | Country 620| URL https://comtrade.un.org/api/get?r=620&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Portugal_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | State of Palestine | 70/84 (~83%)
# WORKING ON | Country 275| URL https://comtrade.un.org/api/get?r=275&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_State of Palestine_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Qatar | 71/84 (~85%)
# WORKING ON | Country 634| URL https://comtrade.un.org/api/get?r=634&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Qatar_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Romania | 72/84 (~86%)
# WORKING ON | Country 642| URL https://comtrade.un.org/api/get?r=642&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Romania_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Russian Federation | 73/84 (~87%)
# WORKING ON | Country 643| URL https://comtrade.un.org/api/get?r=643&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Russian Federation_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Saudi Arabia | 74/84 (~88%)
# WORKING ON | Country 682| URL https://comtrade.un.org/api/get?r=682&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Saudi Arabia_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Singapore | 75/84 (~89%)
# WORKING ON | Country 702| URL https://comtrade.un.org/api/get?r=702&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Singapore_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | San Marino | 76/84 (~90%)
# WORKING ON | Country 674| URL https://comtrade.un.org/api/get?r=674&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_San Marino_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Slovakia | 77/84 (~92%)
# WORKING ON | Country 703| URL https://comtrade.un.org/api/get?r=703&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Slovakia_2016_ref_20200809_1327.csv | COMPLETE
# COPY   | SKIP
# Working on | Syria | 78/84 (~93%)
# WORKING ON | Country 760| URL https://comtrade.un.org/api/get?r=760&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Syria_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP
# Working on | Turkmenistan | 79/84 (~94%)
# WORKING ON | Country 795| URL https://comtrade.un.org/api/get?r=795&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Turkmenistan_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP
# Working on | Timor-Leste | 80/84 (~95%)
# WORKING ON | Country 626| URL https://comtrade.un.org/api/get?r=626&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Timor-Leste_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP
# Working on | Turkey | 81/84 (~96%)
# WORKING ON | Country 792| URL https://comtrade.un.org/api/get?r=792&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Turkey_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP
# Working on | Uzbekistan | 82/84 (~98%)
# WORKING ON | Country 860| URL https://comtrade.un.org/api/get?r=860&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Uzbekistan_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP
# Working on | Holy See (Vatican City State) | 83/84 (~99%)
# WORKING ON | Country 336| URL https://comtrade.un.org/api/get?r=336&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Holy See (Vatican City State)_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP
# Working on | Yemen | 84/84 (~100%)
# WORKING ON | Country 887| URL https://comtrade.un.org/api/get?r=887&p=all&freq=A&ps=2016&cc=TOTAL
# OBLIGATORY PAUSE
# Export | ../Data/0_raw/1_auto_download/dl_un_com_Yemen_2016_ref_20200809_1328.csv | COMPLETE
# COPY   | SKIP

# %%
# check number of entries (should be 93 regardless)
len(df_collection)
for entry in df_collection:
    if len(entry) == 2:
        print(entry)
    else:
        pass

# %%
# rename
dl_year = "2016"
# merge all dataframes
df_un_com_master = pd.concat(df_collection)
# save entire download to download folder
s_file_export.f_df_export(df_un_com_master,f"un_com_{dl_year}",p_copy= False,p_loc1=path_raw_dl,p_loc1_pre="dl_",p_file_id=f"{notebook_id}_")
# Out:
# Export | ../Data/0_raw/1_auto_download/122_dl_un_com_2016_20200809_1334.csv | COMPLETE
# COPY   | SKIP

# %% [markdown]
# <a id="ID_part3"></a>
# ### Part 3 | Refine UN dataset
# || [0| Default imports](#ID_top) || [1|Part1](#ID_part1) || [2|Part2](#ID_part2) || [3|Part3](#ID_part3) || [4|Part4](#ID_part4) || [5|Part5](#ID_part5) ||

# %%
            # Partner / reporter info (6)
columns =   ["rtCode","rt3ISO","rtTitle","ptCode","pt3ISO","ptTitle",
             # period and trade category and value information (3)
             "period","rgDesc","yr",
             # duplicate info? (6)
             "rgCode","cmdCode","TradeValue","periodDesc","pfCode","cmdDescE"]

df_un_com_focused = df_un_com_master.loc[:,columns]
df_un_com_focused.head()
# Out:
#    rtCode rt3ISO               rtTitle  ptCode pt3ISO      ptTitle  period  \
# 0     784    ARE  United Arab Emirates       0    WLD        World    2016
# 1     784    ARE  United Arab Emirates       0    WLD        World    2016
# 2     784    ARE  United Arab Emirates       0    WLD        World    2016
# 3     784    ARE  United Arab Emirates       4    AFG  Afghanistan    2016
# 4     784    ARE  United Arab Emirates       4    AFG  Afghanistan    2016
#
#       rgDesc    yr  rgCode cmdCode    TradeValue periodDesc pfCode  \
# 0     Import  2016       1   TOTAL  270779148786       2016     H4
# 1     Export  2016       2   TOTAL  295046691148       2016     H4
# 2  Re-Export  2016       3   TOTAL  145112606991       2016     H4
# 3     Import  2016       1   TOTAL     244526143       2016     H4
# 4     Export  2016       2   TOTAL    1596610735       2016     H4
#
#           cmdDescE
# 0  All Commodities
# 1  All Commodities
# 2  All Commodities
# 3  All Commodities
# 4  All Commodities

# %%
# save year specific data frame
s_file_export.f_df_export(df_un_com_focused,f"un_com_{dl_year}_mini",p_file_id=f"{notebook_id}_")
# Out:
# Export | ../Data/1_raw_processed_backup/122_store_un_com_2016_mini_20200809_1336.csv | COMPLETE
# COPY   | ../Data/2_raw_processed_input/122_input_un_com_2016_mini.csv.gzip | COMPLETE
