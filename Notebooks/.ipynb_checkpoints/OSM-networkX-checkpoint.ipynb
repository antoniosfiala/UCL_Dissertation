# %%
pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# https://github.com/Tofull/networkx-osm

# %%
import osmnx as ox
import time

# %%
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %%
place = "Norfolk, United Kingdom"
graph = ox.graph_from_place(place, custom_filter = '["power"~"line"]')

# %%
graph.nodes()
# Out:
# NodeView((2430463488, 2430463489, 2430463490, 2430463491, 2430463492, 2430463493, 2430463494, 2430463496, 2430463497, 2430463499, 2430463501, 1245643789, 2430463503, 2430463504, 2430463506, 2430463508, 2430463509, 2430463510, 2430463512, 2430463513, 2430463514, 2430463515, 2430463517, 2430463518, 2430463519, 2430463521, 2430463522, 2430463523, 2430463524, 2430463525, 2430463526, 2430463527, 2430463528, 2430463529, 2430463530, 2430463531, 2430463532, 2430463533, 2430463534, 2430463535, 2430463536, 361457720, 361457722, 1245608535, 1245608554, 454163311, 454163316, 361457782, 454163326, 1245643655, 364096934, 346160563, 1245643706, 364096716, 364096717, 454163408, 346160607, 2430463475, 2430463476, 2430463477, 2430463478, 2430463479, 2430463480, 2430463481, 2430463482, 2430463483, 2430463484, 2430463485, 2430463486, 2430463487))

# %%
nx.draw_spring(graph)

# %% [markdown]
# Primitive country downloader

# %%
start = time.time()
place = "Kyrgyzstan"
rail_graph = ox.graph_from_place(place, custom_filter = '["railway"~"rail"]')
#freight_rail_graph = ox.graph_from_place(place, custom_filter = '["railway"~"rail|freight"]')
#rail|freight|
end = time.time()

# %%
print(f"Time taken {(end-start)/60} minutes")

# %%
len(rail_graph)

# %%
nodes, edges = ox.graph_to_gdfs(rail_graph)

# %%
edges
# Out:
#        osmid tunnel  oneway     ref                  name maxspeed   length  \
# 0  182695883    yes    True  930000  Monaco - Monte Carlo       60   15.905
# 1  444971012    yes    True  930000  Monaco - Monte Carlo       90  145.364
# 2  444971011    yes    True  930000  Monaco - Monte Carlo       60   27.819
# 3  182695886    yes    True  930000  Monaco - Monte Carlo       90  144.940
# 4  444971010    yes    True  930000  Monaco - Monte Carlo       60   15.132
# 5  182695884    yes   False  930000  Monaco - Monte Carlo       60  101.464
# 6  235977378    yes    True  930000  Monaco - Monte Carlo       60   28.527
# 7  182695884    yes   False  930000  Monaco - Monte Carlo       60  101.464
#
#                                             geometry           u           v  \
# 0    LINESTRING (7.42001 43.73843, 7.41983 43.73837)  1690189849  1930545590
# 1  LINESTRING (7.42001 43.73843, 7.41960 43.73821...  1690189849  1690189833
# ...

# %%
rail_graph

# %%
len(freight_rail_graph)
# Out:
# 1106

# %%
plt.figure(1,figsize = (60,60),dpi = 150)
nx.draw_spring(rail_graph,)

# %%
plt.figure(1,figsize = (60,60),dpi = 150)
nx.draw_spring(rail_graph,)

# %%
custom_filter : string
    a custom network filter to be used instead of the network_type presets,
    e.g., '["power"~"line"]' or '["highway"~"motorway|trunk"]'. Also pass
    in a network_type that is in settings.bidirectional_network_types if
    you want graph to be fully bidirectional.
